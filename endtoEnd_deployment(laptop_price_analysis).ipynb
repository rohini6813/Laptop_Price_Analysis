# %% [markdown]
# <a href="https://colab.research.google.com/github/rohini6813/Laptop_Price_Analysis/blob/main/endtoEnd_deployment(laptop_price_analysis).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as pe

# %%
df = pd.read_csv("/content/drive/MyDrive/R K Data Analytic/Colab Notebooks/Data Set/laptop_price.csv",  encoding = 'unicode_escape')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.tail()
# Out:
#       laptop_ID Company                              Product  \
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 1298  2 in 1 Convertible    14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  2 in 1 Convertible    13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300            Notebook    14.0                                    1366x768
# 1301            Notebook    15.6                                    1366x768
# 1302            Notebook    15.6                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.sample()
# Out:
#      laptop_ID Company        Product  TypeName  Inches   ScreenResolution  \
# 621        628  Lenovo  ThinkPad T470  Notebook    14.0  Full HD 1920x1080
#
#                             Cpu  Ram     Memory                    Gpu  \
# 621  Intel Core i5 6200U 2.3GHz  8GB  256GB SSD  Intel HD Graphics 520
#
#          OpSys  Weight  Price_euros
# 621  Windows 7  1.65kg       1465.0

# %%
df.shape
# Out:
# (1303, 13)

# %%
df['TypeName'].value_counts()
# Out:
# TypeName
# Notebook              727
# Gaming                205
# Ultrabook             196
# 2 in 1 Convertible    121
# Workstation            29
# Netbook                25
# Name: count, dtype: int64

# %%
df['Product'].value_counts()
# Out:
# Product
# XPS 13                                     30
# Inspiron 3567                              29
# 250 G6                                     21
# Legion Y520-15IKBN                         19
# Vostro 3568                                19
#                                            ..
# 15-bw007nv (A10-9620P/6GB/128GB/Radeon      1
# SmartBook 130                               1
# A541NA-GO342 (N3350/4GB/500GB/Linux)        1
# 17-X047na (i3-6006U/8GB/1TB/W10)            1
# V330-15IKB (i5-8250U/4GB/500GB/FHD/W10)     1
# Name: count, Length: 618, dtype: int64

# %%
df.drop(columns = ['laptop_ID', 'Product'], inplace = True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df.isnull().sum()
# Out:
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 29

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (1274, 11)

# %%
df.sample(1)
# Out:
#     Company  TypeName  Inches                     ScreenResolution  \
# 639    Dell  Notebook    15.6  4K Ultra HD / Touchscreen 3840x2160
#
#                              Cpu   Ram   Memory                      Gpu  \
# 639  Intel Core i7 7700HQ 2.8GHz  16GB  1TB SSD  Nvidia GeForce GTX 1050
#
#           OpSys  Weight  Price_euros
# 639  Windows 10  2.06kg       2399.0

# %%
#convert the price_euros to INR
df['Price_euros'] = round(df['Price_euros']*89.07).astype('int')

# %%
df.sample(2)
# Out:
#     Company  TypeName  Inches   ScreenResolution                          Cpu  \
# 513    Dell  Notebook    15.6  Full HD 1920x1080   Intel Core i7 8550U 1.8GHz
# 591  Lenovo  Notebook    15.6  Full HD 1920x1080  AMD A12-Series 9720P 3.6GHz
#
#       Ram                Memory             Gpu       OpSys Weight  \
# 513  16GB  256GB SSD +  2TB HDD  AMD Radeon 530  Windows 10  2.2kg
# 591  12GB             512GB SSD  AMD Radeon 530  Windows 10  2.2kg
#
#      Price_euros
# 513       108598
# 591        84527

# %%
df.rename(columns = {'Price_euros':'Price'}, inplace = True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight   Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg  119326
# 1        Intel HD Graphics 6000  macOS  1.34kg   80069
# 2         Intel HD Graphics 620  No OS  1.86kg   51215
# ...

# %%
#another way -> df.Ram
df['Ram'].value_counts()
# Out:
# Ram
# 8GB     613
# 4GB     366
# 16GB    198
# 6GB      35
# 12GB     25
# 32GB     17
# 2GB      16
# 24GB      3
# 64GB      1
# Name: count, dtype: int64

# %%
a = 'GB'
type(a)
# Out:
# str

# %%
a.replace("GB", " ")
# Out:
# ' '

# %%
#one line code / apply function to entire col at once
(lambda a :a.replace("GB", " "))
# Out:
# <function __main__.<lambda>(a)>

# %%
df['Ram'] = df['Ram'].apply(lambda a :a.replace("GB", " ")).astype('int')

# %%
df.head(1)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                     Cpu  Ram     Memory                           Gpu  OpSys  \
# 0  Intel Core i5 2.3GHz    8  128GB SSD  Intel Iris Plus Graphics 640  macOS
#
#    Weight   Price
# 0  1.37kg  119326

# %%
df['Ram'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Ram'>

# %%
#the black line represent outliers(away from the grp)
sns.barplot( x = df['Ram'], y = df['Price'])
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
df['Weight'].value_counts()
# Out:
# Weight
# 2.2kg     116
# 2.1kg      58
# 2.4kg      42
# 2.5kg      38
# 2.3kg      37
#          ...
# 1.14kg      1
# 3.8kg       1
# 1.19kg      1
# 1.55kg      1
# 4.0kg       1
# Name: count, Length: 179, dtype: int64

# %%
#kde -> represent the data using a continuous probability density curve in one or more dimensions
sns.displot(x = df['Weight'], kde = True)

# %%
sns.scatterplot(x = df['Weight'], y = df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %%
df['Weight'] = df['Weight'].apply(lambda a :a.replace("kg", " ")).astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1273
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1274 non-null   object
#  1   TypeName          1274 non-null   object
#  2   Inches            1274 non-null   float64
#  3   ScreenResolution  1274 non-null   object
#  4   Cpu               1274 non-null   object
#  5   Ram               1274 non-null   int64
#  6   Memory            1274 non-null   object
#  7   Gpu               1274 non-null   object
#  8   OpSys             1274 non-null   object
#  9   Weight            1274 non-null   float64
#  10  Price             1274 non-null   int64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 119.4+ KB

# %%
df['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         151
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
df['Company'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Company'>

# %%
#filtering for the company which are repeated more than 10 time
df = df[df.groupby('Company')['Company'].transform('count') > 10]

# %%
sns.barplot( x = df['Company'], y = df['Price'])
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
sns.barplot( x = df['TypeName'], y = df['Price'])
plt.xticks(rotation = 90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Ultrabook'),
#   Text(1, 0, 'Notebook'),
#   Text(2, 0, 'Netbook'),
#   Text(3, 0, 'Gaming'),
#   Text(4, 0, '2 in 1 Convertible'),
#   Text(5, 0, 'Workstation')])

# %%
df['Inches'].value_counts()
# Out:
# Inches
# 15.6    636
# 14.0    182
# 17.3    162
# 13.3    152
# 12.5     37
# 11.6     29
# 12.0      6
# 13.9      6
# 15.4      4
# 10.1      4
# 18.4      1
# 17.0      1
# 14.1      1
# 11.3      1
# 15.0      1
# Name: count, dtype: int64

# %%
df = df[df.groupby('Inches')["Inches"].transform('count') > 10]

# %%
df['Inches'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Inches'>

# %%
sns.barplot(x = df['Inches'], y = df['Price'], palette = 'viridis')
# Out:
# <ipython-input-45-0a7c5c2c5604>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = df['Inches'], y = df['Price'], palette = 'viridis')
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
sns.scatterplot(x = df['Inches'], y = df['Price'], palette = 'viridis')
# Out:
# <ipython-input-46-34d639e8e81e>:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.scatterplot(x = df['Inches'], y = df['Price'], palette = 'viridis')
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
df.sample()
# Out:
#     Company            TypeName  Inches  \
# 470      HP  2 in 1 Convertible    13.3
#
#                                   ScreenResolution  \
# 470  IPS Panel 4K Ultra HD / Touchscreen 3840x2160
#
#                             Cpu  Ram     Memory                     Gpu  \
# 470  Intel Core i7 8550U 1.8GHz    8  512GB SSD  Intel UHD Graphics 620
#
#           OpSys  Weight   Price
# 470  Windows 10    1.29  178051

# %%
#pixcel per inches | more ppi more quality
# PPI = √ (Horizontal pixels ^2 + Vertical pixels ^2) / Diagonal screen size

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                491
# 1366x768                                         256
# IPS Panel Full HD 1920x1080                      217
# Full HD / Touchscreen 1920x1080                   44
# IPS Panel Full HD / Touchscreen 1920x1080         43
# 1600x900                                          22
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# ...

# %%
a = 'IPS Panel Touchscreen / 4K Ultra HD 3840x2160'
#x_res = 3840 and y_res = 2160

# %%
a
# Out:
# 'IPS Panel Touchscreen / 4K Ultra HD 3840x2160'

# %%
a.split()[-1]
# Out:
# '3840x2160'

# %%
a.split()[-1].split('x')
# Out:
# ['3840', '2160']

# %%
a.split()[-1].split('x')[0]
# Out:
# '3840'

# %%
a.split()[-1].split('x')[1]
# Out:
# '2160'

# %%
df['x_res'] = df['ScreenResolution'].apply(lambda a : a.split()[-1].split('x')[0]).astype('int')

# %%
df['y_res'] = df['ScreenResolution'].apply(lambda a : a.split()[-1].split('x')[1]).astype('int')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook    15.6                            1366x768
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
#
#                             Gpu       OpSys  Weight   Price  x_res  y_res
# 0  Intel Iris Plus Graphics 640       macOS    1.37  119326   2560   1600
# 1        Intel HD Graphics 6000       macOS    1.34   80069   1440    900
# ...

# %% [markdown]
# ##Lambda theory with practical explanation

# %%
#add a col for ppi
#x_res, y_res, inches
df['ppi'] = round(((df['x_res']**2) + (df['y_res']**2)) ** 0.5 / df['Inches'])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 5    Acer   Notebook    15.6                            1366x768
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
# 5     AMD A9-Series 9420 3GHz    4            500GB HDD
#
#                             Gpu       OpSys  Weight   Price  x_res  y_res  \
# 0  Intel Iris Plus Graphics 640       macOS    1.37  119326   2560   1600
# 1        Intel HD Graphics 6000       macOS    1.34   80069   1440    900
# ...

# %%
df['ppi'].value_counts()
# Out:
# ppi
# 141.0    419
# 100.0    194
# 127.0    131
# 157.0    122
# 166.0    100
# 112.0     42
# 135.0     28
# 276.0     25
# 176.0     25
# 282.0     23
# 106.0     22
# 210.0     18
# 125.0      9
# 118.0      8
# 331.0      7
# 227.0      6
# 255.0      5
# 128.0      4
# 352.0      2
# 170.0      2
# 91.0       2
# 221.0      2
# 190.0      1
# 235.0      1
# Name: count, dtype: int64

# %% [markdown]
# the line represent the hyperplan use to define the cluster

# %%
sns.regplot(x = df['ppi'], y = df['Price'])
# Out:
# <Axes: xlabel='ppi', ylabel='Price'>

# %% [markdown]
# interview question

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                491
# 1366x768                                         256
# IPS Panel Full HD 1920x1080                      217
# Full HD / Touchscreen 1920x1080                   44
# IPS Panel Full HD / Touchscreen 1920x1080         43
# 1600x900                                          22
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160      8
# 4K Ultra HD / Touchscreen 3840x2160                8
# 4K Ultra HD 3840x2160                              7
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# IPS Panel Retina Display 2560x1600                 6
# IPS Panel Touchscreen 2560x1440                    5
# 1440x900                                           4
# ...

# %%
a = 'IPS Panel Touchscreen / 4K Ultra HD 3840x2160'
(lambda a: 1 if "IPS" in a else 0)('Quad HD+ 3200x1800')
# Out:
# 0

# %%
df['IPS'] = df['ScreenResolution'].apply(lambda a: 1 if "IPS" in a else 0)

# %%
df.sample(2)
# Out:
#      Company   TypeName  Inches   ScreenResolution  \
# 761     Dell  Ultrabook    12.5  Full HD 1920x1080
# 1016      HP   Notebook    15.6           1366x768
#
#                              Cpu  Ram     Memory                    Gpu  \
# 761   Intel Core i7 7600U 2.8GHz   16  256GB SSD  Intel HD Graphics 620
# 1016  Intel Core i3 7100U 2.4GHz    4  256GB SSD  Intel HD Graphics 620
#
#            OpSys  Weight   Price  x_res  y_res    ppi  IPS
# 761   Windows 10    1.18  165581   1920   1080  176.0    0
# 1016  Windows 10    2.04   68583   1366    768  100.0    0

# %%
df['Touchscreen'] = df['IPS'] = df['ScreenResolution'].apply(lambda a: 1 if "Touchscreen" in a else 0)

# %%
df['Touchscreen'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %%
df.drop(columns = ['ScreenResolution', 'Inches', 'x_res', 'y_res'], inplace = True)

# %%
df.head(1)
# Out:
#   Company   TypeName                   Cpu  Ram     Memory  \
# 0   Apple  Ultrabook  Intel Core i5 2.3GHz    8  128GB SSD
#
#                             Gpu  OpSys  Weight   Price    ppi  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37  119326  227.0    0
#
#    Touchscreen
# 0            0

# %%
df.shape
# Out:
# (1198, 12)

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz     183
# Intel Core i7 7700HQ 2.8GHz    142
# Intel Core i7 7500U 2.7GHz     122
# Intel Core i5 8250U 1.6GHz      70
# Intel Core i7 8550U 1.8GHz      68
#                               ...
# AMD E-Series E2-9000 2.2GHz      1
# Intel Core i5 2.0GHz             1
# Intel Core M M3-6Y30 0.9GHz      1
# AMD A9-Series 9420 2.9GHz        1
# AMD A9-Series 9410 2.9GHz        1
# Name: count, Length: 100, dtype: int64

# %%
a = 'Intel Core i5 7200U 2.5GHz'
a.split()[0:3]
# Out:
# ['Intel', 'Core', 'i5']

# %%
(lambda a: " ".join(a.split()[0:3]))
# Out:
# <function __main__.<lambda>(a)>

# %%
df['Cpu'] = df['Cpu'].apply(lambda a: " ".join(a.split()[0:3]))

# %%
df['Cpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
#filter the AMD cpu wrt series
#AMD E-Series E2-9000 2.2GHz	 >> AMD E-Series

# %%
def fetch_pro(text):
  if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
    return text
  elif text.split()[0] == 'Intel':
    return "Other Intel Processor"
  else:
    if text[4] =='E':
      return "AMD E-Series"
    elif text[4] == 'A':
      return "AMD A-Series"
    elif text[4] == 'F':
      return "AMD F-Series"
    else:
      return "AMD Ryzen Series"

# %%
fetch_pro('Intel Atom x5-Z8350')
# Out:
# 'Other Intel Processor'

# %%
df['Cpu'].apply(fetch_pro)
# Out:
# 0               Intel Core i5
# 1               Intel Core i5
# 2               Intel Core i5
# 4               Intel Core i5
# 5                AMD A-Series
#                 ...
# 1269            Intel Core i7
# 1270            Intel Core i7
# 1271            Intel Core i7
# 1272    Other Intel Processor
# 1273            Intel Core i7
# Name: Cpu, Length: 1198, dtype: object

# %%
df['Cpu'] = df['Cpu'].apply(fetch_pro)

# %%
df['Cpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Cpu'>

# %%
sns.barplot(x = df['Cpu'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %%
df['Gpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
df.sample(5)
# Out:
#      Company            TypeName                    Cpu  Ram  \
# 970     Dell  2 in 1 Convertible          Intel Core i7   16
# 740     Dell            Notebook          Intel Core i7    8
# 1090    Dell            Notebook  Other Intel Processor    4
# 87        HP            Notebook          Intel Core i5    8
# 941     Asus            Notebook  Other Intel Processor    4
#
#                     Memory                    Gpu       OpSys  Weight   Price  \
# 970              512GB SSD  Intel HD Graphics 615  Windows 10    1.22  169144
# 740   128GB SSD +  1TB HDD   Nvidia GeForce 940MX  Windows 10    2.00  107507
# 1090             500GB HDD      Intel HD Graphics       Linux    2.20   35048
# 87               256GB SSD  Intel HD Graphics 620  Windows 10    1.96   53352
# 941                1TB HDD   Nvidia GeForce 920MX  Windows 10    2.80   47207
#
#         ppi  IPS  Touchscreen
# 970   276.0    1            1
# 740   141.0    0            0
# 1090  100.0    0            0
# ...

# %%
a = 'Intel HD Graphics 620'

# %%
a.split()[0:2]
# Out:
# ['Intel', 'HD']

# %%
lambda a: " ".join(a.split()[0:2])
# Out:
# <function __main__.<lambda>(a)>

# %%
df['Gpu'] = df['Gpu'].apply(lambda a: " ".join(a.split()[0:2]))

# %%
df['Gpu'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Gpu'>

# %%
sns.barplot(x = df['Gpu'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %%
df.sample(1)
# Out:
#     Company TypeName            Cpu  Ram                Memory  \
# 653     MSI   Gaming  Intel Core i7    8  128GB SSD +  1TB HDD
#
#                 Gpu       OpSys  Weight   Price    ppi  IPS  Touchscreen
# 653  Nvidia GeForce  Windows 10     2.2  106154  141.0    0            0

# %%
df['OpSys'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='OpSys'>

# %%
#where we have Window 10 or window 10 S >> Window 10
#Window 7 >> Window 7
#macOS or Mac OS X >> Mac OS
df['OpSys'] = df['OpSys'].apply(lambda a: " ".join(a.split()[0:2]))

# %%
sns.barplot(x = df['OpSys'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# or

# %%
def os(text):
  if text == "Window 10" or text == "Window 10 S":
    return "Window 10"
  elif text == "Window 7":
    return "Window 7"
  elif text == "Mac Os" or text == "macOS":
    return "mac OS"
  elif text == "No OS":
    return   "No OS"
  elif text == "Linux":
    return "Linux"
  else:
    return "Chrome OS"

# %%
sns.barplot(x = df['OpSys'], y = df['Price'])
plt.xticks(rotation = 90)
plt.show()

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        387
# 1TB HDD                          213
# 500GB HDD                        122
# 512GB SSD                         99
# 128GB SSD +  1TB HDD              93
# 256GB SSD +  1TB HDD              73
# 128GB SSD                         71
# 32GB Flash Storage                28
# 2TB HDD                           16
# 512GB SSD +  1TB HDD              13
# 1TB SSD                           12
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       7
# 64GB Flash Storage                 6
# 16GB Flash Storage                 6
# 256GB Flash Storage                5
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 32GB SSD                           2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
#flash storage
#SSD
#HDD
#hybride
new = df['Memory'].str.split('+', n = 1, expand = True)
df['first'] = new[0]
df['first'] = df['first'].str.strip() #strip -> use any white space / extra space
df['second'] = new[1]

df['Layer1HDD'] = df['first'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '', regex = True)  #regex -> to search for validate or manipulate str and pattern in text

df['second'].fillna("0", inplace = True)

df['second'] = df['second'].str.strip()
df['Layer2HDD'] = df['second'].apply(lambda x: 1 if "HDD" in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x: 1 if "SSD" in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x: 1 if "Hybrid" in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '', regex = True)

df['first'] = df['first'].astype('int')
df['second'] = df['second'].astype('int')

df['HDD'] = df['first']*df['Layer1HDD'] + df['second']*df['Layer2HDD']
df['SSD'] = df['first']*df['Layer1SSD'] + df['second']*df['Layer2HDD']
df['Hybrid'] = df['first']*df['Layer1Hybrid'] + df['second']*df['Layer2Hybrid']
df['Flash_Storage'] = df['first']* df['Layer1Flash_Storage'] + df['second']* df['Layer2Flash_Storage']

df.drop(columns = ['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid', 'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid', 'Layer2Flash_Storage'], inplace = True)
# Out:
# <ipython-input-99-6233c64e4cb7>:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['second'].fillna("0", inplace = True)

# %%
df.sample(5)
# Out:
#       Company            TypeName            Cpu  Ram                Memory  \
# 621    Lenovo            Notebook  Intel Core i5    8             256GB SSD
# 526    Lenovo            Notebook  Intel Core i7    4               1TB HDD
# 79         HP            Notebook  Intel Core i5    8  128GB SSD +  1TB HDD
# 665   Toshiba            Notebook  Intel Core i3    4             128GB SSD
# 1202     Dell  2 in 1 Convertible  Intel Core i7   16             512GB SSD
#
#                  Gpu       OpSys  Weight   Price    ppi  IPS  Touchscreen  \
# 621         Intel HD   Windows 7    1.65  130488  157.0    0            0
# 526   Nvidia GeForce  Windows 10    2.20   71167  141.0    0            0
# 79    Nvidia GeForce  Windows 10    2.50   87021  127.0    0            0
# 665         Intel HD  Windows 10    2.10   44357  100.0    0            0
# 1202       Intel UHD  Windows 10    2.00  114455  141.0    1            1
#
#       HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.to_csv("Cleaned.csv")
